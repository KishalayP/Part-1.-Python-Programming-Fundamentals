# %% [markdown]
# # 1. BOOLEANS

# %%
# Boolean values can be represented as one of two constant objects "False" and "True". 
# Booleans behave like integers 0 and 1.
a= True
b=a+False
b
# Out:
# 1

# %%
False
# Out:
# False

# %%
stock_1_price=200
stock_2_price=200
print(stock_1_price == stock_2_price)
# Out:
# True

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **What will this code generate?**
# ```
# stock_1_price = 20
# stock_2_price = 30
# print((stock_1_price < stock_2_price))
# print(stock_1_price == stock_2_price)
# ```

# %%
stock_1_price = 20
stock_2_price = 30
print(stock_1_price < stock_2_price)
print(stock_1_price == stock_2_price)
# Out:
# True
# False

# %% [markdown]
# # 2. LIST

# %%
# A list is a collection which is ordered and changeable. 
# List allows duplicate members.
list=[1,2,3]
list
# Out:
# [1, 2, 3]

# %%
# Obtain the datatype
type (list)
# Out:
# list

# %%
# list with mixed datatypes (for example you can have strings and integers in one list)
m_list=[1,2.3,3.4,"Jai Radha Krishna",8.4476]
m_list
# Out:
# [1, 2.3, 3.4, 'Jai Radha Krishna', 8.4476]

# %%
# You can have a list inside another list (nested list)
n_list=[1,'Jai Siya Ram',[3,5,8]]
n_list
# Out:
# [1, 'Jai Siya Ram', [3, 5, 8]]

# %%
# Access specific elements in the list with Indexing
# Note that the first element in the list has an index of 0 (little confusing but you'll get used to it!)
listee=[2,'GOOG',5]
listee[2]
# Out:
# 5

# %%
# indexing for nested lists
n_list=[1,'Jai Siya Ram',[3,6,8],[1,2.3,3.4,"Jai Radha Krishna",8.4476],['APPL', 5, 6]]
print(n_list[3][3])
print(n_list[1])
# Out:
# Jai Radha Krishna
# Jai Siya Ram

# %%
n_list[2][1]
# Out:
# 6

# %%
n_list[4]
# Out:
# ['APPL', 5, 6]

# %%
# Negative Indexing
my_list=[2,'GOOG',5]
my_list[-2]
# Out:
# 'GOOG'

# %%
# List Slicing (getting more than one element from a list) 
my_list=[2,5,7,'GOOG','SP500','AMZN',15]
# obtain elements starting from index 3 up to and not including element with index 6  
my_list[3:-1]
# Out:
# ['GOOG', 'SP500', 'AMZN']

# %%
# Obtain elements starting from index 3 to end
my_list[3:]
# Out:
# ['GOOG', 'SP500', 'AMZN', 15]

# %%
# All elements start to end
my_list[:]
# Out:
# [2, 5, 7, 'GOOG', 'SP500', 'AMZN', 15]

# %%
# Obtain the length of the list (how many elements in the list) 
len(my_list)
# Out:
# 7

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Print the first, second and last element in the list below**
# - **Print all elements in the list, first 3 elements, and last three elements**
#
# ```
# stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
# ```

# %%
stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
print(stocks[0])
print(stocks[1])
print(stocks[-1])
print(stocks[:])
print(stocks[0:3])
print(stocks[-3:])
# Out:
# GOOG
# TSLA
# EUR/USD
# ['GOOG', 'TSLA', 'AAPL', 'T', 'SP500', 'BTC', 'EUR/USD']
# ['GOOG', 'TSLA', 'AAPL']
# ['SP500', 'BTC', 'EUR/USD']

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Print GOOG**
# - **Print AAPL, GOOG, TSLA**
# - **Print T with two different ways**
#
# ```
# my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]
# ```

# %%
my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]
print(my_list[1][1])
print(my_list[1])
print(my_list[3])
print(my_list[-1])
# Out:
# GOOG
# ['AAPL', 'GOOG', 'TSLA']
# T
# T

# %% [markdown]
# # 3. DICTIONARY

# %%
# my_dict = {'key1':'value1', 'key2':'value2', 'key3':'value3'}
# Dictionary consists of a collection of key-value pairs. Each key-value pair maps the key to its corresponding value.
# Keys are unique within a dictionary while values may not be. 
# List elements are accessed by their position in the list, via indexing while Dictionary elements are accessed via keys
my_dict={'key1':'value1',
         'key2':'value2',
         'key3':'value3',
         'key4':'value4'
         }
# Define a dictionary using key-value pairs

# %%
# View the dictionary
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3', 'key4': 'value4'}

# %%
# Check the data type
type(my_dict)
# Out:
# dict

# %%
# Access specific element in the dictionary using a specific key (ex: Key2)
my_dict['key2']
# Out:
# 'value2'

# %%
# Define a dictionary for a bank client listing all his/her assets! 
ClientD={'Real Estate':150000,'Stocks':10000,'Savings':20000}

# %%
# Access elements in the dictionary
ClientD['Stocks']
# Out:
# 10000

# %%
# Add a new item to an existing dictionary
ClientD['Crypto']=1500
ClientD
# Out:
# {'Crypto': 1500, 'Real Estate': 150000, 'Savings': 20000, 'Stocks': 10000}

# %%
# remove an item from the dictionary
del ClientD['Savings']
print(ClientD)
# Out:
# {'Real Estate': 150000, 'Stocks': 10000, 'Crypto': 1500}

# %%
# delete the entire dictionary
# Note that you cannot print it out again because the entire dictionary has been deleted
del ClientD
print(ClientD)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-41dd81653951> in <module>()
#       2 # Note that you cannot print it out again because the entire dictionary has been deleted
#       3 del ClientD
# ----> 4 print(ClientD)
#
# NameError: name 'ClientD' is not defined

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Create a dictionary with 3 of your favourite stocks and their prices**

# %%
Fav_Stock={'AMZN':1500,'GOOGL':250,'AAPL':450}
Fav_Stock
# Out:
# {'AAPL': 450, 'AMZN': 1500, 'GOOGL': 250}

# %% [markdown]
# # 4. STRINGS

# %%
# A string in Python is a sequence of characters
# String can be enclosed by either double or single quotes
my_string='Hello Everone and Welcome to Python for Finance course'
my_string
# Out:
# 'Hello Everone and Welcome to Python for Finance course'

# %%
# Obtain the datatype
type(my_string)
# Out:
# str

# %%
# Combining two strings together (Let's combine the first and last name of a bank's client)
first_name="Jai"
last_name="Siya Ram"
fulle_name=first_name+last_name
fulle_name
# Out:
# 'JaiSiya Ram'

# %%
# You can combine both strings together and add spaces in between
fulle_name=first_name+" "+last_name
fulle_name
# Out:
# 'Jai Siya Ram'

# %%
# Methods on strings 
# upper will be used to convert the string into upper case
fulle_name.upper()
# Out:
# 'JAI SIYA RAM'

# %%
# Split us used to divide up the string into words 
# The output from split is a list
x=my_string.split()
print(x)
print(type(x))
# Out:
# ['Hello', 'Everone', 'and', 'Welcome', 'to', 'Python', 'for', 'Finance', 'course']
# <class 'list'>

# %%
# Let's check that the datatype is list!
type(x)
# Out:
# list

# %%
# you can index any element in the list using indexing
x[1]
# Out:
# 'Everone'

# %%
# you can specify which letter could be choosed to perform the split
my_string='laila.aly@gmail.com'
z=my_string.split('@')
z
# Out:
# ['laila.aly', 'gmail.com']

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Write a code that takes an input from a bank client asking him/her about their feedback regarding the service. The code should split the client input into words and print them on screen**

# %%
fb=input("Please Give you're feedback: ")
fb = str (fb)
z= fb.split()
print(z)
# Out:
# Please Give you're feedback: Imma lovin it
# ['Imma', 'lovin', 'it']

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Write a code that prompts a user requesting his/her e-mail and then extracts the user first name (Note that the e-mail is in firstname.lastname@gmail.com**

# %%
email=input("PLease enter you're e-mail: ")
email= str(email)
h=email.split("@")
h=h[0].split(".")
print(h[0])
# Out:
# PLease enter you're e-mail: kishalay.pandey@gmail.com
# kishalay

# %% [markdown]
# # 5. TUPLES

# %%
# A tuple is a sequence of immutable Python objects. 
# Tuples are sequences, just like lists. 
# The differences between tuples and lists are, the tuples cannot be changed unlike lists and tuples use parentheses, whereas lists use square brackets.

# %%
tuple_1=('GOOG','APPL',10,15,1992);
tuple_2=(450,55,977,2100)
type(tuple_1)
# Out:
# tuple

# %%
tuple_1
# Out:
# ('GOOG', 'APPL', 10, 15, 1992)

# %%
# Accessing elements in a tuple
tuple_1[1]
# Out:
# 'APPL'

# %%
# Tuple slicing
tuple_1[1:-2]
# Out:
# ('APPL', 10)

# %%
# Changing a vlue of a tuple does not work! 
# 'tuple' object does not support item assignment
tuple_1[1]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-ec66cb24c28f> in <module>()
#       1 # Changing a vlue of a tuple does not work!
#       2 # 'tuple' object does not support item assignment
# ----> 3 tuple_1[1]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Create a New Tuple from existing Tuples
tuple_3=tuple_1+tuple_2
tuple_3
# Out:
# ('GOOG', 'APPL', 10, 15, 1992, 450, 55, 977, 2100)

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Define a tuple with your first name, last name, age and the number of stocks in your portfolio. Find the length and type as well.**

# %%
Me=('Kishalay','Pandey',22,5)
print(Me)
print(type(Me))
print(len(Me))
# Out:
# ('Kishalay', 'Pandey', 22, 5)
# <class 'tuple'>
# 4

# %% [markdown]
# # 6. SETS

# %%
# A set is an unordered collection of items. Every element is unique (no duplicates).
# A set is created by placing all the items (elements) inside curly braces {}, separated by comma or by using the built-in function set().
# set of integers
my_set={'GOOG','APPL','TSLA'}
print(my_set)
# Out:
# {'APPL', 'GOOG', 'TSLA'}

# %%
# set do not have duplicates
my_Set={'T', 'AAPL', 'GOOG', 'TSLA', 'AAPL','T'}
print(my_Set)
# Out:
# {'T', 'TSLA', 'GOOG', 'AAPL'}

# %% [markdown]
# **MINI CHALLENGE #8:**
# - **Remove the duplicates from the following list:**
#
#
# ```
# my_list = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6,5]
# ```

# %%
my_sets = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6,5]
nmy_sets=list(set(my_sets))
print(nmy_sets)
# Out:
# ['AAPL', 5, 6, 'APPL', 'T', 'GOOG', 'TSLA']

# %% [markdown]
# # MINI CHALLENGE SOLUTIONS

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **What will this code generate?**
# ```
# stock_1_price = 20
# stock_2_price = 30
# print((stock_1_price < stock_2_price))
# print(stock_1_price == stock_2_price)
# ```

# %%
stock_1_price = 20
stock_2_price = 30
print((stock_1_price < stock_2_price))
print(stock_1_price == stock_2_price)
# Out:
# True
# False

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Print the first, second and last element in the list**
# - **Print all elements in the list, first 3 elements, and last three elements**
#
# ```
# stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
# ```

# %%
stocks = ["GOOG", "TSLA", "AAPL", "T", "SP500", "BTC", "EUR/USD"]
print(stocks[0])
print(stocks[1])
print(stocks[-1])
# Out:
# GOOG
# TSLA
# EUR/USD

# %%
print(stocks[:])
print(stocks[0:3])
print(stocks[4:])

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Print GOOG**
# - **Print AAPL, GOOG, TSLA**
# - **Print T with two different ways**
#
# ```
# my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]
# ```

# %%
my_list = ["SP500", ["AAPL", "GOOG", "TSLA"], "BTC", "T"]

# %%
print(my_list[1][1])
# Out:
# GOOG

# %%
print(my_list[1])
# Out:
# ['AAPL', 'GOOG', 'TSLA']

# %%
print(my_list[3])
# Out:
# T

# %%
print(my_list[-1])
# Out:
# T

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Create a dictionary with 3 of your favourite stocks and their prices**

# %%
stocks = {"SP500": 3000, 
          "AAPL": 400,
          "TSLA": 2200}
print(stocks)
# Out:
# {'SP500': 3000, 'AAPL': 400, 'TSLA': 2200}

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Write a code that takes an input from a bank client asking him/her about their feedback regarding the service. The code should split the client input into words and print them on screen**

# %%
my_string = str(input("What did we do at the bank today? are you satisfied with the service"))
words = my_string.split(" ")
print("Here are the list of words you entered:", words)
# Out:
# What did we do at the bank today? are you satisfied with the serviceMy experience today was positive, the service is perfect! great job everyone
# Here are the list of words you entered: ['My', 'experience', 'today', 'was', 'positive,', 'the', 'service', 'is', 'perfect!', 'great', 'job', 'everyone']

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Write a code that prompts a user requesting his/her e-mail and then extracts the user first name (Note that the e-mail is in firstname.lastname@gmail.com**

# %%
input_str = input("Welcome to the bank, please enter your e-mail address:")
out_str = input_str.split('@')
out_str = out_str[0].split('.')
print(out_str[0])
# Out:
# Enter your e-mail address:ryan.ahmed@yahoo.com
# ryan

# %% [markdown]
# **MINI CHALLENGE #7 SOLUTION:**
# - **Define a tuple with your first name, last name, age and the number of stocks in your portfolio. Find the length and type as well.**

# %%
my_tuple = ("Ryan", "ahmed", 25, 10)
print(my_tuple)
# Out:
# ('Ryan', 'ahmed', 25, 10)

# %%
len(my_tuple)
# Out:
# 4

# %%
type(my_tuple)
# Out:
# tuple

# %% [markdown]
# **MINI CHALLENGE #8 SOLUTION:**
# - **Remove the duplicates from the following list:**
#
#
# ```
# my_list = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6,5]
# ```

# %%
my_list = ['GOOG', 'APPL', 'T','TSLA','T','AAPL', 5, 6, 5]
out_list = list(set(my_list))
print(out_list)
# Out:
# [5, 6, 'T', 'APPL', 'GOOG', 'TSLA', 'AAPL']
